# %%
from instagram_scraper import InstagramScraper
# Out:
# Searching alexachung for profile pic: 100% 1/1 [00:00<00:00, 771.58 images/s]
# Searching alexachung for posts: 451 media [00:09, 15.75 media/s]
# Downloading: 100%|##########| 485/485 [00:13<00:00, 35.00it/s]
# Searching weworewhat for profile pic: 100% 1/1 [00:00<00:00, 1267.54 images/s]
# Searching weworewhat for posts: 451 media [00:26,  4.11 media/s]
# ...
# Downloading:  98%|#########8| 446/455 [00:09<00:01,  5.13it/s]
# Searching weworewhat for posts: 451 media [00:40,  4.11 media/s]A
# Downloading: 100%|##########| 455/455 [00:15<00:00,  1.96it/s]
#
# Searching juliahengel for profile pic:   0% 0/1 [00:00<?, ? images/s]
# Searching juliahengel for profile pic: 100% 1/1 [00:00<00:00, 887.50 images/s]
# Searching juliahengel for posts: 0 media [00:00, ? media/s]
# Searching juliahengel for posts: 1 media [00:03,  3.49s/ media]
# Searching juliahengel for posts: 51 media [00:07,  2.47s/ media]
# Searching juliahengel for posts: 101 media [00:09,  1.74s/ media]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('../src/scraping/ig_influencers.csv', names=['ighandle'])

# %%
df.head()
# Out:
#          ighandle
# 0      alexachung
# 1      weworewhat
# 2     juliahengel
# 3  chiaraferragni
# 4       gabifresh

# %%
args = dict(usernames=df.ighandle.values.tolist(),
            destination='../insta_data/',
            retain_username=True,
            quite=True,
            maximum=500,
            media_metadata=True,
            profile_metadata=True,
            media_types=['image', 'story-image'],
            tag=True, location=True)

# %%
iscraper = InstagramScraper(**args)

# %%
iscraper.authenticate_as_guest()

# %%
iscraper.usernames
# Out:
# ['alexachung',
#  'weworewhat',
#  'juliahengel',
#  'chiaraferragni',
#  'gabifresh',
#  'imjennim',
#  'susiebubble',
#  'nicolettemason',
#  'leandramcohen',
#  'majawyh',
#  'candela_________',
#  'camillecharriere',
#  'garancedore',
#  'pandorasykes',
#  'galagonzalez',
#  'inesdelafressangeofficial',
#  'jeannedamas',
#  'madelynnfurlong',
#  'thefrugality',
#  'double3xposure',
#  'bat_gio',
#  'patriciamanfield',
#  'helenabordon',
#  'oliviapalermo',
#  'weworewhat',
#  'alexandralapp_',
#  'revolve',
#  'giorgiatordini',
#  'veronikaheilbrunner',
#  'kyliejenner',
#  'gemmatalbot',
#  'sabinasocol',
#  'miamiamine',
#  'little_magpie1',
#  'newdarlings',
#  'emmahill',
#  'imjennim',
#  'ariadibari',
#  'liuwenlw',
#  'captainmiao',
#  'bingbing_fan',
#  'paudictado',
#  'kendalljenner',
#  'kimkardashian',
#  'hkloekaradshian',
#  'priyankachopra',
#  'deepikapadukone']

# %%
iscraper.scrape()

# %%
l = !ls -lh ../insta_data/
l
# Out:
# ['total 0',
#  'drwxr-xr-x   501 hongdouli  staff    16K Apr 23 13:30 alexachung',
#  'drwxr-xr-x   636 hongdouli  staff    20K Apr 23 13:50 alexandralapp_',
#  'drwxr-xr-x   123 hongdouli  staff   3.8K Apr 23 13:59 ariadibari',
#  'drwxr-xr-x   591 hongdouli  staff    18K Apr 23 13:46 bat_gio',
#  'drwxr-xr-x   419 hongdouli  staff    13K Apr 23 14:02 bingbing_fan',
#  'drwxr-xr-x   513 hongdouli  staff    16K Apr 23 13:40 camillecharriere',
#  'drwxr-xr-x   532 hongdouli  staff    17K Apr 23 13:39 candela_________',
#  'drwxr-xr-x   846 hongdouli  staff    26K Apr 23 14:01 captainmiao',
#  'drwxr-xr-x   892 hongdouli  staff    28K Apr 23 13:33 chiaraferragni',
#  'drwxr-xr-x   496 hongdouli  staff    16K Apr 23 14:06 deepikapadukone',
#  'drwxr-xr-x   538 hongdouli  staff    17K Apr 23 13:45 double3xposure',
#  'drwxr-xr-x   647 hongdouli  staff    20K Apr 23 13:58 emmahill',
#  'drwxr-xr-x   557 hongdouli  staff    17K Apr 23 13:34 gabifresh',
# ...
