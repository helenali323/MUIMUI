# %%
import pandas as pd

# %%
from pathlib import Path

# %%
p = Path('../insta_data/')

# %%
dirnames = [str(i) for i in p.iterdir()]

# %%
filenames = []
for folder in dirnames:
    p = Path(folder)
    filenames += [str(i) for i in p.iterdir() if str(i)[-3:]=='jpg']

# %%
len(filenames)
# Out:
# 26035

# %%
import cv2

# %%
def imread(fname):
    im = cv2.imread(str(fname))
    # openCV by default uses BGR ordering but we need RBG usually
    # height x width x channels
    return cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
df = pd.DataFrame(columns=['fname', 'img'])

# %%
df.fname = filenames

# %%
df.head()
# Out:
#                                                fname  img
# 0  ../insta_data/hkloekaradshian/51101368_2097866...  NaN
# 1  ../insta_data/hkloekaradshian/47694171_7705880...  NaN
# 2  ../insta_data/hkloekaradshian/49722019_1583065...  NaN
# 3  ../insta_data/hkloekaradshian/47500699_3065716...  NaN
# 4  ../insta_data/hkloekaradshian/50719506_2851739...  NaN

# %%
df['img'] = df.fname.apply(lambda x: imread(x).shape)

# %%
df.to_csv('df.csv',index=False)

# %%
df = pd.read_csv('df.csv')
df
# Out:
#                                                    fname              img  \
# 0      ../insta_data/hkloekaradshian/51101368_2097866...    (792, 634, 3)
# 1      ../insta_data/hkloekaradshian/47694171_7705880...    (900, 720, 3)
# 2      ../insta_data/hkloekaradshian/49722019_1583065...    (720, 720, 3)
# 3      ../insta_data/hkloekaradshian/47500699_3065716...    (900, 720, 3)
# 4      ../insta_data/hkloekaradshian/50719506_2851739...    (900, 720, 3)
# 5      ../insta_data/hkloekaradshian/47586031_2009241...    (801, 727, 3)
# 6      ../insta_data/hkloekaradshian/56405600_2998611...  (1280, 1024, 3)
# 7      ../insta_data/hkloekaradshian/46182409_1276749...    (557, 557, 3)
# 8      ../insta_data/hkloekaradshian/50716171_1323813...  (1352, 1080, 3)
# 9      ../insta_data/hkloekaradshian/46287203_3061754...    (893, 720, 3)
# 10     ../insta_data/hkloekaradshian/46148666_5705276...    (889, 711, 3)
# 11     ../insta_data/hkloekaradshian/47095825_3758126...  (1349, 1079, 3)
# 12     ../insta_data/hkloekaradshian/50737490_6608983...   (769, 1080, 3)
# 13     ../insta_data/hkloekaradshian/52644961_1218420...    (900, 720, 3)
# 14     ../insta_data/hkloekaradshian/50341034_4447207...    (893, 720, 3)
# 15     ../insta_data/hkloekaradshian/45369973_1040521...    (868, 694, 3)
# 16     ../insta_data/hkloekaradshian/47582627_8146170...  (1262, 1010, 3)
# 17     ../insta_data/hkloekaradshian/51309060_8414205...    (720, 720, 3)
# 18     ../insta_data/hkloekaradshian/53599199_2386381...    (900, 720, 3)
# 19     ../insta_data/hkloekaradshian/47692774_1666152...  (1024, 1024, 3)
# 20     ../insta_data/hkloekaradshian/50556888_3258454...    (900, 720, 3)
# 21     ../insta_data/hkloekaradshian/49290807_5946987...    (720, 730, 3)
# 22     ../insta_data/hkloekaradshian/56862499_3647886...  (1280, 1024, 3)
# 23     ../insta_data/hkloekaradshian/49393752_2740176...    (710, 720, 3)
# 24     ../insta_data/hkloekaradshian/51612920_2177030...    (900, 720, 3)
# 25     ../insta_data/hkloekaradshian/47582743_7467260...  (1350, 1080, 3)
# 26     ../insta_data/hkloekaradshian/47583121_2863321...    (895, 715, 3)
# 27     ../insta_data/hkloekaradshian/51407008_2350006...    (900, 720, 3)
# 28     ../insta_data/hkloekaradshian/55847245_5642993...    (856, 720, 3)
# 29     ../insta_data/hkloekaradshian/51287124_1636274...    (898, 720, 3)
# ...                                                  ...              ...
# 26005  ../insta_data/alexachung/41158126_498049737336...  (1080, 1080, 3)
# 26006  ../insta_data/alexachung/46890523_644721552608...  (1080, 1080, 3)
# 26007  ../insta_data/alexachung/31310894_126125852731...    (750, 750, 3)
# 26008  ../insta_data/alexachung/39196281_257305494902...   (807, 1080, 3)
# 26009  ../insta_data/alexachung/36160516_211448424880...   (810, 1080, 3)
# 26010  ../insta_data/alexachung/39927806_682974532075...    (525, 700, 3)
# 26011  ../insta_data/alexachung/44887340_190777290267...  (1350, 1080, 3)
# 26012  ../insta_data/alexachung/36160247_250228429093...  (1350, 1080, 3)
# 26013  ../insta_data/alexachung/45829551_266386744011...  (1080, 1080, 3)
# 26014  ../insta_data/alexachung/41373103_225061281854...    (741, 741, 3)
# 26015  ../insta_data/alexachung/47692588_116398607709...  (1080, 1080, 3)
# 26016  ../insta_data/alexachung/36512720_288416998565...    (750, 750, 3)
# 26017  ../insta_data/alexachung/56345967_354016911886...  (1080, 1080, 3)
# 26018  ../insta_data/alexachung/33239817_195837164394...  (1080, 1080, 3)
# 26019  ../insta_data/alexachung/56270328_433404883894...  (1080, 1080, 3)
# 26020  ../insta_data/alexachung/50959067_275006612503...   (726, 1080, 3)
# 26021  ../insta_data/alexachung/39019258_181676279510...    (560, 750, 3)
# 26022  ../insta_data/alexachung/42002855_341147123319...   (1152, 929, 3)
# 26023  ../insta_data/alexachung/38674209_314539509292...  (1350, 1080, 3)
# 26024  ../insta_data/alexachung/42098524_266483987336...    (288, 500, 3)
# 26025  ../insta_data/alexachung/47694621_287415625275...    (768, 768, 3)
# 26026  ../insta_data/alexachung/38809036_264232197533...    (495, 660, 3)
# 26027  ../insta_data/alexachung/52771932_564169694082...  (1080, 1080, 3)
# 26028  ../insta_data/alexachung/41539237_579650699119...  (1080, 1080, 3)
# 26029  ../insta_data/alexachung/41866157_463375167505...  (1080, 1080, 3)
# 26030  ../insta_data/alexachung/32594745_202379578120...   (767, 1030, 3)
# 26031  ../insta_data/alexachung/43012489_319045055545...   (1000, 800, 3)
# 26032  ../insta_data/alexachung/30085118_492968894433...  (1080, 1080, 3)
# 26033  ../insta_data/alexachung/56517214_425747728006...  (1080, 1080, 3)
# 26034  ../insta_data/alexachung/47693310_195018050505...  (1080, 1080, 3)
#
#        position
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12        False
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21        False
# 22         True
# 23        False
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
# ...         ...
# 26005      True
# 26006      True
# 26007      True
# 26008     False
# 26009     False
# 26010     False
# 26011      True
# 26012      True
# 26013      True
# 26014      True
# 26015      True
# 26016      True
# 26017      True
# 26018      True
# 26019      True
# 26020     False
# 26021     False
# 26022      True
# 26023      True
# 26024     False
# 26025      True
# 26026     False
# 26027      True
# 26028      True
# 26029      True
# 26030     False
# 26031      True
# 26032      True
# 26033      True
# 26034      True
#
# [26035 rows x 3 columns]

# %%
df.img.value_counts()
# Out:
# (1350, 1080, 3)    10862
# (1080, 1080, 3)     4857
# (1349, 1080, 3)     2725
# (1346, 1080, 3)      368
# (1345, 1080, 3)      291
# (720, 1080, 3)       154
# (810, 1080, 3)       147
# (1079, 1080, 3)      144
# (809, 1080, 3)       122
# (1348, 1080, 3)      119
# (640, 640, 3)         98
# (750, 750, 3)         92
# (1171, 937, 3)        74
# (1078, 1080, 3)       71
# (1024, 1024, 3)       64
# (1352, 1080, 3)       57
# (1082, 1080, 3)       53
# (320, 320, 3)         45
# (1347, 1080, 3)       42
# (900, 720, 3)         39
# (1339, 1080, 3)       39
# (719, 1080, 3)        38
# (1000, 1000, 3)       36
# (1336, 1080, 3)       34
# (800, 800, 3)         34
# (1342, 1080, 3)       32
# (721, 1079, 3)        32
# (937, 750, 3)         30
# (1337, 1080, 3)       29
# (607, 1080, 3)        28
#                    ...
# (620, 621, 3)          1
# (718, 811, 3)          1
# (1055, 1080, 3)        1
# (582, 582, 3)          1
# (864, 693, 3)          1
# (1046, 925, 3)         1
# (1049, 887, 3)         1
# (1153, 925, 3)         1
# (530, 663, 3)          1
# (914, 731, 3)          1
# (1087, 903, 3)         1
# (633, 639, 3)          1
# (1021, 1022, 3)        1
# (477, 720, 3)          1
# (860, 1032, 3)         1
# (1043, 1043, 3)        1
# (350, 350, 3)          1
# (1050, 840, 3)         1
# (1308, 1046, 3)        1
# (315, 482, 3)          1
# (581, 771, 3)          1
# (610, 1080, 3)         1
# (909, 800, 3)          1
# (752, 752, 3)          1
# (708, 708, 3)          1
# (464, 750, 3)          1
# (543, 783, 3)          1
# (710, 568, 3)          1
# (1020, 1080, 3)        1
# (793, 634, 3)          1
# Name: img, Length: 1715, dtype: int64

# %%
df['position'] = df.img.apply(lambda x: x[0] >= x[1])

# %%
df.position.value_counts()
# Out:
# False    26035
# Name: position, dtype: int64

# %%
df[df.position == False]['fname']
# Out:
# 0        ../insta_data/hkloekaradshian/51101368_2097866...
# 1        ../insta_data/hkloekaradshian/47694171_7705880...
# 2        ../insta_data/hkloekaradshian/49722019_1583065...
# 3        ../insta_data/hkloekaradshian/47500699_3065716...
# 4        ../insta_data/hkloekaradshian/50719506_2851739...
# 5        ../insta_data/hkloekaradshian/47586031_2009241...
# 6        ../insta_data/hkloekaradshian/56405600_2998611...
# 7        ../insta_data/hkloekaradshian/46182409_1276749...
# 8        ../insta_data/hkloekaradshian/50716171_1323813...
# 9        ../insta_data/hkloekaradshian/46287203_3061754...
# 10       ../insta_data/hkloekaradshian/46148666_5705276...
# 11       ../insta_data/hkloekaradshian/47095825_3758126...
# 12       ../insta_data/hkloekaradshian/50737490_6608983...
# 13       ../insta_data/hkloekaradshian/52644961_1218420...
# 14       ../insta_data/hkloekaradshian/50341034_4447207...
# 15       ../insta_data/hkloekaradshian/45369973_1040521...
# 16       ../insta_data/hkloekaradshian/47582627_8146170...
# 17       ../insta_data/hkloekaradshian/51309060_8414205...
# 18       ../insta_data/hkloekaradshian/53599199_2386381...
# 19       ../insta_data/hkloekaradshian/47692774_1666152...
# 20       ../insta_data/hkloekaradshian/50556888_3258454...
# 21       ../insta_data/hkloekaradshian/49290807_5946987...
# 22       ../insta_data/hkloekaradshian/56862499_3647886...
# 23       ../insta_data/hkloekaradshian/49393752_2740176...
# 24       ../insta_data/hkloekaradshian/51612920_2177030...
# 25       ../insta_data/hkloekaradshian/47582743_7467260...
# 26       ../insta_data/hkloekaradshian/47583121_2863321...
# 27       ../insta_data/hkloekaradshian/51407008_2350006...
# 28       ../insta_data/hkloekaradshian/55847245_5642993...
# 29       ../insta_data/hkloekaradshian/51287124_1636274...
#                                ...
# 26005    ../insta_data/alexachung/41158126_498049737336...
# 26006    ../insta_data/alexachung/46890523_644721552608...
# 26007    ../insta_data/alexachung/31310894_126125852731...
# 26008    ../insta_data/alexachung/39196281_257305494902...
# 26009    ../insta_data/alexachung/36160516_211448424880...
# 26010    ../insta_data/alexachung/39927806_682974532075...
# 26011    ../insta_data/alexachung/44887340_190777290267...
# 26012    ../insta_data/alexachung/36160247_250228429093...
# 26013    ../insta_data/alexachung/45829551_266386744011...
# 26014    ../insta_data/alexachung/41373103_225061281854...
# 26015    ../insta_data/alexachung/47692588_116398607709...
# 26016    ../insta_data/alexachung/36512720_288416998565...
# 26017    ../insta_data/alexachung/56345967_354016911886...
# 26018    ../insta_data/alexachung/33239817_195837164394...
# 26019    ../insta_data/alexachung/56270328_433404883894...
# 26020    ../insta_data/alexachung/50959067_275006612503...
# 26021    ../insta_data/alexachung/39019258_181676279510...
# 26022    ../insta_data/alexachung/42002855_341147123319...
# 26023    ../insta_data/alexachung/38674209_314539509292...
# 26024    ../insta_data/alexachung/42098524_266483987336...
# 26025    ../insta_data/alexachung/47694621_287415625275...
# 26026    ../insta_data/alexachung/38809036_264232197533...
# 26027    ../insta_data/alexachung/52771932_564169694082...
# 26028    ../insta_data/alexachung/41539237_579650699119...
# 26029    ../insta_data/alexachung/41866157_463375167505...
# 26030    ../insta_data/alexachung/32594745_202379578120...
# 26031    ../insta_data/alexachung/43012489_319045055545...
# 26032    ../insta_data/alexachung/30085118_492968894433...
# 26033    ../insta_data/alexachung/56517214_425747728006...
# 26034    ../insta_data/alexachung/47693310_195018050505...
# Name: fname, Length: 26035, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(imread(df.fname[25971]))

# %%
im = imread(df.fname[26512])

# %%
im.shape
# Out:
# (743, 495, 3)

# %%
WHITE = [255,255,255]

# %%
im.shape[0] > im.shape[1]
# Out:
# True

# %%
max(im.shape[0], im.shape[1])
# Out:
# 743

# %%
diff = abs(im.shape[0] - im.shape[1])
diff
# Out:
# 248

# %%
# top, bottom, left, right
imb = cv2.copyMakeBorder(im, 0, 0, int(diff/2), int(diff/2), cv2.BORDER_CONSTANT,value=WHITE)

# %%
plt.imshow(imb)

# %%
def im_squared(im, col=[255, 255, 255]):
    v, h = im.shape[0], im.shape[1]
    diff = abs(h - v)
    pad = int(diff/2)
    if v > h:
        return cv2.copyMakeBorder(im, 0, 0, pad, pad, cv2.BORDER_CONSTANT,value=col)
    else:
        return cv2.copyMakeBorder(im, pad, pad, 0, 0, cv2.BORDER_CONSTANT, value=col)

# %%
plt.imshow(imread(df.fname[1000]))

# %%
plt.imshow(im_squared(imread(df.fname[1000])))

# %%
imread(df.fname[13080]).shape
# Out:
# (186, 224, 3)

# %%
plt.imshow(im_squared(imread(df.fname[13080])))

# %%
im_squared(imread(df.fname[13080])).shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(im_squared(imread(df.fname[13080])))

# %%
def imsave(im, fname):
    cv2.imwrite(fname, cv2.cvtColor(im, cv2.COLOR_RGB2BGR))

# %%
def resize(im, new_height=None, new_width=None, scale=0.5):
    """resizes images"""
    r, c, _ = im.shape

    if new_height is None and new_width is None and scale is not None:
        # keeping the same aspect ratio as original
        new_height = int(scale * r)
        new_width = int(scale * c)
    elif new_height is None and new_width is not None:
        # use the scale based on old and new width
        scale = float(new_width) / float(c)
        new_height = int(scale * r)
    elif new_height is not None and new_width is None:
        # use the scale based on old and new height
        scale = float(new_height) / float(r)
        new_width = int(scale * c)
    elif new_height is not None and new_width is not None:
        # just use the new height and old height
        pass
    else:
        raise InvalidInputException('Invalid input configuration')

    imr = cv2.resize(im, (new_width, new_height))
    return imr

# %%
sz = 512

# %%
from fastprogress import progress_bar
from concurrent.futures import ProcessPoolExecutor, as_completed

# %%
def parallel(func, job_list, n_jobs=16):
    with ProcessPoolExecutor(max_workers=n_jobs) as pool:
        futures = [pool.submit(func, job) for job in job_list]
        for f in progress_bar(as_completed(futures), total=len(job_list)):
            pass
    return [f.result() for f in futures]

# %%
def convert(fname):
    im = imread(fname)
    imb = im_squared(im)
    imr = resize(imb, sz, sz)
    imsave(imr, fname.replace('train', 'resized'))

# %%
convert(df.fname[0])

# %%
job_list = df.fname.values

# %%
len(job_list)
# Out:
# 26035

# %%
result = parallel(convert, job_list)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='26035' class='' max='26035', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [26035/26035 03:17<00:00]
#     </div>

# %%
for n in range(100,len(job_list),100):
    result = parallel(convert, job_list[n-100:n])
# Out:
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/Users/hongdouli/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/hongdouli/anaconda3/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/hongdouli/anaconda3/lib/python3.6/concurrent/futures/process.py", line 295, in _queue_management_worker
#     shutdown_worker()
#   File "/Users/hongdouli/anaconda3/lib/python3.6/concurrent/futures/process.py", line 253, in shutdown_worker
#     call_queue.put_nowait(None)
#   File "/Users/hongdouli/anaconda3/lib/python3.6/multiprocessing/queues.py", line 129, in put_nowait
#     return self.put(obj, False)
#   File "/Users/hongdouli/anaconda3/lib/python3.6/multiprocessing/queues.py", line 83, in put
#     raise Full
# queue.Full
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-42-734767e79ce0> in <module>
#       1 for n in range(100,len(job_list),100):
# ----> 2     result = parallel(convert, job_list[n-100:n])
#
# <ipython-input-34-f06a4bed0264> in parallel(func, job_list, n_jobs)
#       4         for f in progress_bar(as_completed(futures), total=len(job_list)):
#       5             pass
# ----> 6     return [f.result() for f in futures]
#
# <ipython-input-34-f06a4bed0264> in <listcomp>(.0)
#       4         for f in progress_bar(as_completed(futures), total=len(job_list)):
#       5             pass
# ----> 6     return [f.result() for f in futures]
#
# ~/anaconda3/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     423                 raise CancelledError()
#     424             elif self._state == FINISHED:
# --> 425                 return self.__get_result()
#     426
#     427             self._condition.wait(timeout)
#
# ~/anaconda3/lib/python3.6/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
l1 = set(list(Path('../kaggle_resized/').iterdir()))

# %%
l2 = set(list(Path('../kaggle_train/').iterdir()))

# %%
l1 = set([str(k).split('/')[-1] for k in l1])

# %%
l2 = set([str(k).split('/')[-1] for k in l2])

# %%
l2 - l1
# Out:
# {'214012.jpg'}

# %%
l1 - l2
# Out:
# set()
